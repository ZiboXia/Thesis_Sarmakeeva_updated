# %%
import numpy as np
import matplotlib.pyplot as plt

def load_particle_data(directories):
    for directory in directories:
        dir_str = str(directory)
        globals()[f'par1_{dir_str}'] = np.loadtxt(f'{dir_str}/position_particle_1.txt')
        globals()[f'par1vel_{dir_str}'] = np.loadtxt(f'{dir_str}/velocity_particle_1.txt')

# Usage:
directories = [0, 1, 2, 3, 4, 5,'test']
load_particle_data(directories)

# %%
import pandas as pd
data = pd.read_csv('plot-data-sphere.csv')
velocity = pd.read_csv('plot-data-velocity.csv')
pos = pd.read_csv('plot-data_position_new.csv')

# %%
# plot the data
linienstaerke = 2
MarkerGroesse = 8
fig, ax = plt.subplots(figsize=(8, 5))
#plt.plot(par1[:, 0], offset + par1[:, 3], '*',
ax.plot(par1_0[:, 0][:700],par1_0[:, 3][:700], '--',color ='red',linewidth=linienstaerke, markersize=MarkerGroesse)
ax.plot(par1_1[:, 0][:700],par1_1[:, 3][:700], '--',color ='blue',linewidth=linienstaerke, markersize=MarkerGroesse)
ax.plot(par1_2[:, 0][:700],par1_2[:, 3][:700], '--',color ='green',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.plot(par1_3[:, 0][:600],par1_3[:, 3][:600], '--',color ='orange',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.plot(par1_test[:, 0][:600],par1_test[:, 3][:600], '--',color ='orange',linewidth=linienstaerke, markersize=MarkerGroesse)
ax.plot(pos['x'],pos[' y'], '-',color ='black',linewidth=linienstaerke, markersize=MarkerGroesse)
ax.set_xlabel('time (s)')
ax.set_ylabel('position (cm)')

ax.set_xlim([0, 0.35])
ax.set_ylim([0, 0.05])

ax.set_title('Comparison of the z-position of falling particle', fontsize=15)
ax.legend(['24000 cells','192000 cells', '648000 cells','from the work Nan[1]'])
#plt.axis([0, 0.25, 0, 6])
ax.tick_params(labelsize=14);

# %%
plt.figure(2)
#plt.plot(par1vel_0[:,0][:600], np.sqrt(par1vel_0[:, 1]**2 + par1vel_0[:, 2]**2 + par1vel_0[:, 3]**2)[:600], '--',color = 'red',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.plot(par1vel_1[:, 0][:600], np.sqrt(par1vel_1[:, 1]**2 + par1vel_1[:, 2]**2 + par1vel_1[:, 3]**2)[:600], '--',color = 'blue',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.plot(par1vel_2[:, 0][:600], np.sqrt(par1vel_2[:, 1]**2 + par1vel_2[:, 2]**2 + par1vel_2[:, 3]**2)[:600], '--',color = 'green',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.plot(par1vel_test[:, 0][:600], np.sqrt(par1vel_test[:, 1]**2 + par1vel_test[:, 2]**2 + par1vel_test[:, 3]**2)[:600], '--',color = 'orange',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.plot(velocity['x'],velocity[' y'],'-',color ='black',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.xlabel('time (s)')
plt.ylabel('m/s')
plt.title('Comparison of the velocity of a particle', fontsize=15)
plt.legend(['Experiment [3]_0','Experiment [3]_1', 'Experiment [3]_2','Resolved CFD-DEM'])
#plt.axis([0, 0.25, -20, 0])
plt.tick_params(labelsize=14)

plt.show()

# %%
plt.figure(2)
plt.plot(par1vel_0[:,0][:600],-0.68*par1vel_0[:, 3][:600], '--',color = 'red',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.plot(par1vel_1[:, 0][:600],-0.68*par1vel_1[:, 3][:600], '--',color = 'blue',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.plot(par1vel_2[:, 0][:600], -0.68*par1vel_2[:, 3][:600], '--',color = 'green',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.plot(velocity['x'],velocity[' y'],'-',color ='black',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.xlabel('time (s)')
plt.ylabel('m/s')
plt.title('Comparison of the velocity of a particle', fontsize=15)
plt.legend(['Experiment [3]_0','Experiment [3]_1', 'Experiment [3]_2','Resolved CFD-DEM'])
#plt.axis([0, 0.25, -20, 0])
plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# calculate with Paulina

# %%
import pylab
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(2, 1, 1)

ax.plot(par1vel_0[:,0][:600],(-1)*par1vel_0[:, 3][:600], color='blue', lw=2)
ax.plot(par1vel_1[:,0][:600],(-1)*par1vel_1[:, 3][:600], color='red', lw=2)
ax.plot(par1vel_2[:,0][:600],(-1)*par1vel_2[:, 3][:600], color='green', lw=2)
ax.set_yscale('log')
ax.axis([0.1, 0.25, 0.05, 0.1])
# Out:
# (0.1, 0.25, 0.05, 0.1)

# %%
plt.figure(3)
plt.plot(par1vel_0[:,0][:600],-1*par1vel_0[:, 3][:600], '--',color = 'red',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.plot(par1vel_1[:, 0][:600],-1*par1vel_1[:, 3][:600], '--',color = 'blue',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.plot(par1vel_2[:, 0][:600], -1*par1vel_2[:, 3][:600], '--',color = 'green',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.xlabel('time (s)')
plt.yscale('log')
plt.ylabel('m/s')
plt.title('Comparison of the velocity of a particle', fontsize=15)
plt.legend(['Experiment [3]_0','Experiment [3]_1', 'Experiment [3]_2','Resolved CFD-DEM'])
plt.axis([0.1, 0.25, 0.05, 0.1])
plt.tick_params(labelsize=14)

plt.show()

# %%
particle_density = 1250  # kg/m^3
radius = 0.167 / 100  # converting cm to m
g = 9.81  # m/s^2, gravitational acceleration
rho_fluid = 1000  # kg/m^3, fluid density

# Initial conditions
y = 3.5 / 100  # converting cm to m
v = 0.0  # m/s, initial velocity

# Time stepping parameters
dt = 0.001  # time step, seconds
t = 0  # starting time
re_p = 100

# Lists to store the results for plotting
time_list = []
height_list = []
velocity_list = []

# Determine the number of iterations based on the maximum time of 10 seconds
num_iterations = int(0.3 / dt)

for i in range(num_iterations):
    if y <= 0:
        break  # Stop the loop if the sphere hits the ground
    
    # Appending results to lists
    time_list.append(t)
    height_list.append(y)
    velocity_list.append(v)
    
    A = np.pi * radius**2  # Cross-sectional area
    Cd = 1.42  # Drag coefficient for a sphere
    F_d = 0.5 * Cd * rho_fluid * v**2 * A  # Drag force
    m = (4/3) * np.pi * radius**3 * particle_density  # Mass of the sphere
    a = ((particle_density - rho_fluid) / particle_density) * g - (F_d / m)  # acceleration
    v = v + a * dt  # updating velocity
    y = y + v * dt  # updating position
    t = t + dt  # updating time

# %%
l
# Out:
# 1000

# %%
plt.figure(3)
plt.scatter(24000,-1*par1vel_0[:, 3][200], color = 'red')
plt.scatter(192000,-1*par1vel_1[:, 3][300],color = 'blue')
plt.scatter(648000, -1*par1vel_2[:, 3][300],color = 'green')
plt.scatter(648000, -1*par1vel_2[:, 3][300],color = 'green')
plt.scatter(648000, velocity_list[200],color = 'black') # show that this is close to analytic solution
plt.xlabel('time (s)')
plt.yscale('log')
plt.xscale('log')
plt.ylabel('m/s')
plt.title('Comparison of the velocity of a particle', fontsize=15)
plt.legend(['Experiment [3]_0','Experiment [3]_1', 'Experiment [3]_2','Resolved CFD-DEM'])
#plt.axis([24000, 192000, 648000])
plt.tick_params(labelsize=14)
# only wary a mesh
plt.show()

# %% [markdown]
# ## Case 1
# ### Mesh
# cells:            24000
#
# number of cells of each type:
#     hexahedra:     24000
#
# Overall domain bounding box (0 0 0) (0.01 0.01 0.04)
# number of cells in each direction (20 20 60)
#
# ### Coupling propreties:
#
# forceModels IBpressureForceTest
#
# IBpressureForceProps
# {
#     velFieldName "U";
#     voidfractionFieldName "voidfractionNext";
#     densityFieldName "rho";
#     H "H";
# }
#
# couplingInterval 10;
#
# voidFractionModel IB;
#
# locateModel engineIB;
#
# meshMotionModel noMeshMotion;
#
# regionModel allRegion;
#
# dataExchangeModel twoWayMPI;
#
# ### Solver
#
# deltaT          0.00005
# t = 0.5
# solver name intFoamIB

# %% [markdown]
# ## Case 2
# ### Mesh
# cells:            192000
#
# number of cells of each type:
#     hexahedra:     192000
#
# Overall domain bounding box (0 0 0) (0.01 0.01 0.04)
# number of cells in each direction (40 40 120)
#
# ### Coupling propreties:
#
# forceModels IBpressureForceTest
#
# IBpressureForceProps
# {
#     velFieldName "U";
#     voidfractionFieldName "voidfractionNext";
#     densityFieldName "rho";
#     H "H";
# }
#
# couplingInterval 10;
#
# voidFractionModel IB;
#
# locateModel engineIB;
#
# meshMotionModel noMeshMotion;
#
# regionModel allRegion;
#
# dataExchangeModel twoWayMPI;
#
# ### Solver
#
# deltaT          0.00005
# t = 0.5
# solver name intFoamIB

# %% [markdown]
# ## Case 3
# ### Mesh
# cells:            648000
#
# number of cells of each type:
#     hexahedra:     648000
#
# Overall domain bounding box (0 0 0) (0.01 0.01 0.04)
# number of cells in each direction (60 60 180)
#
# ### Coupling propreties:
#
# forceModels IBpressureForceTest
#
# IBpressureForceProps
# {
#     velFieldName "U";
#     voidfractionFieldName "voidfractionNext";
#     densityFieldName "rho";
#     H "H";
# }
#
# couplingInterval 10;
#
# voidFractionModel IB;
#
# locateModel engineIB;
#
# meshMotionModel noMeshMotion;
#
# regionModel allRegion;
#
# dataExchangeModel twoWayMPI;
#
# ### Solver
#
# deltaT          0.00005
# t = 0.5
# solver name intFoamIB

# %% [markdown]
# ## Case 4
# ### Mesh
# cells:            1536000
#
# number of cells of each type:
#     hexahedra:     1536000
#
# Overall domain bounding box (0 0 0) (0.01 0.01 0.04)
# number of cells in each direction (80 80 240)
#
# ### Coupling propreties:
#
# forceModels IBpressureForceTest
#
# IBpressureForceProps
# {
#     velFieldName "U";
#     voidfractionFieldName "voidfractionNext";
#     densityFieldName "rho";
#     H "H";
# }
#
# couplingInterval 10;
#
# voidFractionModel IB;
#
# locateModel engineIB;
#
# meshMotionModel noMeshMotion;
#
# regionModel allRegion;
#
# dataExchangeModel twoWayMPI;
#
# ### Solver
#
# deltaT          0.00005
# t = 0.5
# solver name intFoamIB

# %%
par1_0_new = np.loadtxt('/home/asa/Desktop/final_cases/falling_sphere/nan/single_ph_1sp_1/DEM/post/position_particle_1.txt')
par1vel_0_new = np.loadtxt('/home/asa/Desktop/final_cases/falling_sphere/nan/single_ph_1sp_1/DEM/post/velocity_particle_1.txt')

# %%
plt.figure(2)
plt.plot(par1vel_0_new[:,0][:600], np.sqrt(par1vel_0_new[:, 1]**2 + par1vel_0_new[:, 2]**2 + par1vel_0_new[:, 3]**2)[:600], '--',color = 'red',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.plot(velocity['x'],velocity[' y'],'-',color ='black',linewidth=linienstaerke, markersize=MarkerGroesse)
plt.xlabel('time (s)')
plt.ylabel('m/s')
plt.title('Comparison of the velocity of a particle', fontsize=15)
plt.legend(['Experiment [3]_0','Experiment [3]_1', 'Experiment [3]_2','Resolved CFD-DEM'])
#plt.axis([0, 0.25, -20, 0])
plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# calculate semi-empirical

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given parameters
particle_density = 1250  # kg/m^3
radius = 0.167 / 100  # converting cm to m
g = 9.81  # m/s^2, gravitational acceleration
rho_fluid = 1000  # kg/m^3, fluid density

# Initial conditions
y = 3.5 / 100  # converting cm to m
v = 0.0  # m/s, initial velocity

# Time stepping parameters
dt = 0.001  # time step, seconds
t = 0  # starting time

# Lists to store the results for plotting
time_list = []
height_list = []
velocity_list = []

# Determine the number of iterations based on the maximum time of 10 seconds
num_iterations = int(0.3 / dt)

for i in range(num_iterations):
    if y <= 0:
        break  # Stop the loop if the sphere hits the ground
    
    A = np.pi * radius**2  # Cross-sectional area
    Cd = 1.27  # Drag coefficient for a sphere
    F_d = 0.5 * Cd * rho_fluid * v**2 * A  # Drag force
    m = (4/3) * np.pi * radius**3 * particle_density  # Mass of the sphere
    a = ((particle_density - rho_fluid) / particle_density) * g - (F_d / m)  # acceleration
    v = v + a * dt  # updating velocity
    y = y + v * dt  # updating position
    t = t + dt  # updating time

    # Appending results to lists
    time_list.append(t)
    height_list.append(y)
    velocity_list.append(v)

# Plotting
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Height (cm)', color=color)
#ax1.plot(time_list, np.array(height_list)*100, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Velocity (m/s)', color=color)
ax2.plot(par1vel_0[:,0][:600], np.sqrt(par1vel_0[:, 1]**2 + par1vel_0[:, 2]**2 + par1vel_0[:, 3]**2)[:600], '--',color = 'blue',linewidth=linienstaerke, markersize=MarkerGroesse)
ax2.plot(par1vel_1[:,0][:600], np.sqrt(par1vel_1[:, 1]**2 + par1vel_1[:, 2]**2 + par1vel_1[:, 3]**2)[:600], '--',color = 'green',linewidth=linienstaerke, markersize=MarkerGroesse)
ax2.plot(par1vel_2[:,0][:600], np.sqrt(par1vel_2[:, 1]**2 + par1vel_2[:, 2]**2 + par1vel_2[:, 3]**2)[:600], '--',color = 'red',linewidth=linienstaerke, markersize=MarkerGroesse)

ax2.plot(time_list, velocity_list, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given parameters
particle_density = 1250  # kg/m^3
radius = 0.167 / 100  # converting cm to m
g = 9.81  # m/s^2, gravitational acceleration
rho_fluid = 1000  # kg/m^3, fluid density

# Initial conditions
y = 3.5 / 100  # converting cm to m
v = 0.0  # m/s, initial velocity

# Time stepping parameters
dt = 0.001  # time step, seconds
t = 0  # starting time
re_p = 100

# Lists to store the results for plotting
time_list = []
height_list = []
velocity_list = []

# Determine the number of iterations based on the maximum time of 10 seconds
num_iterations = int(0.3 / dt)

for i in range(num_iterations):
    if y <= 0:
        break  # Stop the loop if the sphere hits the ground
    
    # Appending results to lists
    time_list.append(t)
    height_list.append(y)
    velocity_list.append(v)
    
    A = np.pi * radius**2  # Cross-sectional area
    Cd = 1.27  # Drag coefficient for a sphere
    F_d = 0.5 * Cd * rho_fluid * v**2 * A  # Drag force
    m = (4/3) * np.pi * radius**3 * particle_density  # Mass of the sphere
    a = ((particle_density - rho_fluid) / particle_density) * g - (F_d / m)  # acceleration
    v = v + a * dt  # updating velocity
    y = y + v * dt  # updating position
    t = t + dt  # updating time



# Plotting
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Height (cm)', color=color)
#ax1.plot(time_list, np.array(height_list)*100, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Velocity (m/s)', color=color)
ax2.plot(par1vel_0[:,0][:600], np.sqrt(par1vel_0[:, 1]**2 + par1vel_0[:, 2]**2 + par1vel_0[:, 3]**2)[:600], '--',color = 'blue',linewidth=linienstaerke, markersize=MarkerGroesse)
ax2.plot(par1vel_1[:,0][:600], np.sqrt(par1vel_1[:, 1]**2 + par1vel_1[:, 2]**2 + par1vel_1[:, 3]**2)[:600], '--',color = 'green',linewidth=linienstaerke, markersize=MarkerGroesse)
ax2.plot(par1vel_2[:,0][:600], np.sqrt(par1vel_2[:, 1]**2 + par1vel_2[:, 2]**2 + par1vel_2[:, 3]**2)[:600], '--',color = 'red',linewidth=linienstaerke, markersize=MarkerGroesse)

ax2.plot(time_list, velocity_list, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given parameters
particle_density = 1250  # kg/m^3
radius = 0.167 / 100  # converting cm to m
g = 9.81  # m/s^2, gravitational acceleration
rho_fluid = 1000  # kg/m^3, fluid density

# Initial conditions
y = 3.5 / 100  # converting cm to m
v = 0.0  # m/s, initial velocity

# Time stepping parameters
dt = 0.001  # time step, seconds
t = 0  # starting time
re_p = 100

# Lists to store the results for plotting
time_list = []
height_list = []
velocity_list = []

# Determine the number of iterations based on the maximum time of 10 seconds
num_iterations = int(0.3 / dt)

for i in range(num_iterations):
    if y <= 0:
        break  # Stop the loop if the sphere hits the ground
    
    # Appending results to lists
    time_list.append(t)
    height_list.append(y)
    velocity_list.append(v)
    
    A = np.pi * radius**2  # Cross-sectional area
    Cd = 1.42  # Drag coefficient for a sphere
    F_d = 0.5 * Cd * rho_fluid * v**2 * A  # Drag force
    m = (4/3) * np.pi * radius**3 * particle_density  # Mass of the sphere
    a = ((particle_density - rho_fluid) / particle_density) * g - (F_d / m)  # acceleration
    v = v + a * dt  # updating velocity
    y = y + v * dt  # updating position
    t = t + dt  # updating time



# Plotting
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(10, 4))

color = 'tab:red'

#ax1.plot(time_list, np.array(height_list)*100, color=color)
#ax1.tick_params(axis='y', labelcolor=color)
ax1.plot(par1vel_0_new[:,0][:600], np.sqrt(par1vel_0_new[:, 1]**2 + par1vel_0_new[:, 2]**2 + par1vel_0_new[:, 3]**2)[:600], '--',color = 'blue',linewidth=linienstaerke, markersize=MarkerGroesse)
ax1.plot(time_list, velocity_list, color=color)
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Velocity (m/s)', color=color)
ax1.tick_params(axis='y', labelcolor=color)



# plot the data
linienstaerke = 2
MarkerGroesse = 8
ax2.plot(par1_0_new[:, 0][:700],par1_0_new[:, 3][:700], '--',color ='black',linewidth=linienstaerke, markersize=MarkerGroesse)
#plt.plot(par1_3[:, 0][:600],par1_3[:, 3][:600], '--',color ='orange',linewidth=linienstaerke, markersize=MarkerGroesse)
ax2.plot(pos['x'],pos[' y'], '-',color ='green',linewidth=linienstaerke, markersize=MarkerGroesse)
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('Position (cm)')
ax2.set_xlim([0, 0.3])
ax2.set_ylim([0, 0.04])
ax.tick_params(labelsize=14);

fig.tight_layout()
plt.show()
